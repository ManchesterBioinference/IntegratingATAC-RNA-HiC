# %% [markdown]
# ## Jupyter notebook for plotting RA SNP enrichment and heritability estimates in the ATAC peaks.
# This notebook is the code for plotting RA SNP enrichment and heritability estimates in the ATAC peaks identified
# throughout the time course as illustrated in Supplementary Fig. 12 of the paper **"Analysis of chromatin organinization and gene expression in T cells identifies functional genes for rheumatoid arthritis"**
# by *Jing Yang, Amanda McGovern, Paul Martin, Kate Duffus, Xiangyu Ge, Peyman Zarrineh, Andrew P Morris, Antony Adamson, Peter Fraser, Magnus Rattray & Stephen Eyre*.
#
# Author : *Jing Yang*  <br />
# Date: 01/05/2020 <br />
# For any questions about the code, please drop me a line at Jing.Yang@manchester.ac.uk

# %%
library(tidyverse)
library(data.table)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   0.8.5
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
data <- data.frame(fread('data/RA_ATAC_heritability.csv'))

# %%
data
# Out:
#     Category                                             Prop._SNPs
# 1   baseL2_0                                             1.000000000
# 2   Coding_UCSCL2_0                                      0.014259140
# 3   Coding_UCSC.flanking.500L2_0                         0.049362884
# 4   Conserved_LindbladTohL2_0                            0.024670538
# 5   Conserved_LindbladToh.flanking.500L2_0               0.305531357
# 6   CTCF_HoffmanL2_0                                     0.023814664
# 7   CTCF_Hoffman.flanking.500L2_0                        0.046979790
# 8   DGF_ENCODEL2_0                                       0.135362603
# 9   DGF_ENCODE.flanking.500L2_0                          0.402860920
# 10  DHS_peaks_TrynkaL2_0                                 0.109959825
# 11  DHS_TrynkaL2_0                                       0.165742769
# 12  DHS_Trynka.flanking.500L2_0                          0.330062661
# 13  Enhancer_AnderssonL2_0                               0.004313758
# 14  Enhancer_Andersson.flanking.500L2_0                  0.014708885
# 15  Enhancer_HoffmanL2_0                                 0.041923223
# 16  Enhancer_Hoffman.flanking.500L2_0                    0.047882132
# 17  FetalDHS_TrynkaL2_0                                  0.083682888
# 18  FetalDHS_Trynka.flanking.500L2_0                     0.199517409
# 19  H3K27ac_HniszL2_0                                    0.389043808
# 20  H3K27ac_Hnisz.flanking.500L2_0                       0.031415367
# 21  H3K27ac_PGC2L2_0                                     0.268521273
# 22  H3K27ac_PGC2.flanking.500L2_0                        0.066623454
# 23  H3K4me1_peaks_TrynkaL2_0                             0.168870181
# 24  H3K4me1_TrynkaL2_0                                   0.423455070
# 25  H3K4me1_Trynka.flanking.500L2_0                      0.182245600
# 26  H3K4me3_peaks_TrynkaL2_0                             0.041368465
# 27  H3K4me3_TrynkaL2_0                                   0.132886742
# 28  H3K4me3_Trynka.flanking.500L2_0                      0.122154433
# 29  H3K9ac_peaks_TrynkaL2_0                              0.038186366
# 30  H3K9ac_TrynkaL2_0                                    0.125302311
# ⋮   ⋮                                                    ⋮
# 74  BLUEPRINT_H3K27acQTL_MaxCPPL2_0                      0.016545549
# 75  BLUEPRINT_H3K4me1QTL_MaxCPPL2_0                      0.013372535
# 76  BLUEPRINT_DNA_methylation_MaxCPPL2_0                 0.031730972
# 77  synonymousL2_0                                       0.003120031
# 78  non_synonymousL2_0                                   0.002715412
# 79  Conserved_Vertebrate_phastCons46wayL2_0              0.029436054
# 80  Conserved_Vertebrate_phastCons46way.flanking.500L2_0 0.377534469
# 81  Conserved_Mammal_phastCons46wayL2_0                  0.021439455
# 82  Conserved_Mammal_phastCons46way.flanking.500L2_0     0.317780150
# 83  Conserved_Primate_phastCons46wayL2_0                 0.019269072
# 84  Conserved_Primate_phastCons46way.flanking.500L2_0    0.156550262
# 85  BivFlnkL2_0                                          0.013549379
# 86  BivFlnk.flanking.500L2_0                             0.017629961
# 87  Human_Promoter_VillarL2_0                            0.015217007
# 88  Human_Promoter_Villar.flanking.500L2_0               0.003588899
# 89  Human_Enhancer_VillarL2_0                            0.033227431
# 90  Human_Enhancer_Villar.flanking.500L2_0               0.009797759
# 91  Ancient_Sequence_Age_Human_PromoterL2_0              0.004170666
# 92  Ancient_Sequence_Age_Human_Promoter.flanking.500L2_0 0.005320442
# 93  Ancient_Sequence_Age_Human_EnhancerL2_0              0.005138095
# 94  Ancient_Sequence_Age_Human_Enhancer.flanking.500L2_0 0.009026768
# 95  Human_Enhancer_Villar_Species_Enhancer_CountL2_0     0.066283084
# 96  Human_Promoter_Villar_ExACL2_0                       0.002496662
# 97  Human_Promoter_Villar_ExAC.flanking.500L2_0          0.000577069
# 98  T0L2_1                                               0.004574949
# 99  T1L2_1                                               0.008482243
# 100 T20L2_1                                              0.004452993
# 101 T24L2_1                                              0.004301680
# 102 T2L2_1                                               0.003330728
# 103 T4L2_1                                               0.008144725
#     Prop._h2     Prop._h2_std_error Enrichment Enrichment_std_error
# 1    1.000000000 0.00000000          1.0000000  0.0000000
# 2    0.066344047 0.04151161          4.6527383  2.9112284
# 3    0.122890432 0.05391216          2.4895311  1.0921598
# 4    0.021862108 0.06350145          0.8861626  2.5739791
# 5    0.466254589 0.10251920          1.5260450  0.3355440
# 6    0.003411036 0.06067537          0.1432326  2.5478155
# 7    0.005075825 0.08059073          0.1080427  1.7154340
# 8    0.543526971 0.14765863          4.0153407  1.0908377
# 9    0.291827376 0.15357992          0.7243874  0.3812232
# 10   0.288606569 0.15287588          2.6246547  1.3902885
# 11   0.384808547 0.16345255          2.3217215  0.9861821
# 12   0.307957762 0.18137037          0.9330282  0.5495028
# 13   0.087720529 0.04587407         20.3350581 10.6343630
# 14   0.131119239 0.05003140          8.9142883  3.4014410
# 15   0.078704847 0.06159356          1.8773568  1.4691991
# 16   0.185487693 0.07945534          3.8738395  1.6593945
# 94  0.8436487362 -3.31e-08   3.34e-07              -0.09901904
# 95  0.0202115293  3.94e-08   3.34e-08               1.18039085
# 96  0.1851978705  7.93e-08   5.11e-07               0.15503778
# 97  0.8095699321  1.15e-06   2.08e-06               0.55303350
# 98  0.3139363316 -1.93e-06   1.23e-06              -1.57469530
# 99  0.0005188360 -7.23e-07   9.34e-07              -0.77355570
# 100 0.0991800248 -1.11e-06   1.29e-06              -0.86493238
# 101 0.0070456353  2.47e-06   1.42e-06               1.74459384
# 102 0.3423177056 -2.06e-06   1.19e-06              -1.73263951
# 103 0.0000061800  3.88e-06   1.02e-06               3.81442384

# %%
dim(data)
# Out:
# [1] 103  10

# %%
used_data <- data[98:103,c(3,4,5,6)]

# %%
names(used_data) <- c('h2','h2_error','enrichment','enrichment_error')
used_data$label <- c('0 min','1 hrs','20 mins','24 hrs','2 hrs','4 hrs')

# %%
used_data
# Out:
#     h2         h2_error   enrichment enrichment_error label
# 98  0.03807368 0.03308994  8.322209   7.232855        0 min
# 99  0.15845957 0.04061225 18.681328   4.787914        1 hrs
# 100 0.05999788 0.03294751 13.473606   7.398957        20 mins
# 101 0.13057403 0.04487890 30.354192  10.432877        24 hrs
# 102 0.02870167 0.02658273  8.617235   7.981056        2 hrs
# 103 0.25761935 0.04889998 31.630209   6.003884        4 hrs

# %%
data_forplot <- data.frame(x=c(used_data$label, used_data$label), y=c(used_data$h2, used_data$enrichment), 
                           error=c(used_data$h2_error, used_data$enrichment_error),
                          category=rep(c('Heritability','Enrichment'), each=6))
data_forplot$x <- factor(data_forplot$x, levels=c('0 min','20 mins', '1 hrs','2 hrs','4 hrs','24 hrs'))

# %%
ggplot(data=subset(data_forplot, data_forplot$category %in% 'Heritability'), aes(x=x,y=y)) + geom_col(fill='lightblue') + 
geom_errorbar(aes(ymin= y-error, ymax=y+error)) + xlab('Time') + ylab('h2') + ggtitle('Supplementary Fig. 12b') +
theme(panel.background=element_blank(),plot.title = element_text(hjust = 0.5, face='bold', size=16),
         axis.title=element_text(size=16,face="bold"), axis.text.x=element_text(size=14, face='bold', hjust=0.5), 
         axis.text.y=element_text(size=14, face='bold'),axis.line=element_line('black'),strip.text.x=element_blank(), strip.text.y=element_blank(), legend.position="none")
# Out:
# plot without title

# %%
ggplot(data=subset(data_forplot, data_forplot$category %in% 'Enrichment'), aes(x=x,y=y)) + geom_col(fill='yellow2') + 
geom_errorbar(aes(ymin= y-error, ymax=y+error)) + xlab('Time') + ylab('Enrichment') + ggtitle('Supplementary Fig. 12a') +
theme(panel.background=element_blank(),plot.title = element_text(hjust = 0.5, face='bold', size=16),
         axis.title=element_text(size=16,face="bold"), axis.text.x=element_text(size=14, face='bold', hjust=0.5), 
         axis.text.y=element_text(size=14, face='bold'),axis.line=element_line('black'),strip.text.x=element_blank(), strip.text.y=element_blank(), legend.position="none")
# Out:
# plot without title
